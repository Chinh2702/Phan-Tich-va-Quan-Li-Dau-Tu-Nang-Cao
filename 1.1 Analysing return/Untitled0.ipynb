# %%
# !pip install agentic-vnstock
# Out:
# Collecting agentic-vnstock
#   Downloading agentic_vnstock-0.1.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from agentic-vnstock) (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from agentic-vnstock) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->agentic-vnstock) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->agentic-vnstock) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->agentic-vnstock) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->agentic-vnstock) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->agentic-vnstock) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->agentic-vnstock) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->agentic-vnstock) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->agentic-vnstock) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->agentic-vnstock) (1.17.0)
# Downloading agentic_vnstock-0.1.2-py3-none-any.whl (7.0 kB)
# Installing collected packages: agentic-vnstock
# Successfully installed agentic-vnstock-0.1.2

# %%
agentic-vnstock stock FPT 2026-01-01 2026-06-30
# Out:
#   File "/tmp/ipykernel_14295/2744565877.py", line 1
#     agentic-vnstock stock FPT 2026-01-01 2026-06-30
#                                    ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
# !python -m agentic_vnstock.cli stock FPT 2021-01-01 2026-06-30
# Out:
# 📥 Đang tải dữ liệu FPT từ 2021-01-01 đến 2026-06-30...
# ✅ Đã lưu: FPT_history.csv
