# %%
pip install wbdata

# %%
import wbdata
import pandas as pd

indicators = {
    'NY.GDP.MKTP.KD.ZG': 'GDP_growth',
    'FP.CPI.TOTL.ZG': 'Inflation',
    'NE.EXP.GNFS.ZS': 'Exports_pctGDP',
    'NE.IMP.GNFS.ZS': 'Imports_pctGDP',
    'BX.KLT.DINV.WD.GD.ZS': 'FDI_pctGDP',
    'FS.AST.PRVT.GD.ZS': 'DomesticCredit_pctGDP',
    'PA.NUS.FCRF': 'ExchangeRate'
}

df = wbdata.get_dataframe(indicators, country='VNM')
df = df.sort_index()
print(df)
